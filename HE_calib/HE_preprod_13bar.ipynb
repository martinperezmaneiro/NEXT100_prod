# %% [markdown]
# # 208Tl preprod
#
# * Check the efficiency of 208Tl simulation

# %%
import pandas as pd
import tables as tb
import glob
import numpy as np
from invisible_cities.io.dst_io import load_dst
import matplotlib.pyplot as plt

# %%
nexus_path = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calibration/{isotope}/prod/{port}/nexus/*.h5'

# %%
# NUMBER OF SIMULATED EVENTS
nevent_per_file = 20000
nfiles_per_port = 660
nevents_per_port = nevent_per_file * nfiles_per_port
nport = 4
nevents = nevents_per_port * nport

# %% [markdown]
# ## 208Tl

# %%
def get_mc_info(f, active = True):
    hit_df = load_dst(f, 'MC', 'hits')
    conf_df = load_dst(f, 'MC', 'configuration')
    if active: hit_df = hit_df[hit_df.label == 'ACTIVE']
    hit_df = hit_df.merge(hit_df.groupby('event_id').energy.sum().rename('tot_ene'), on='event_id')
    hit_df = hit_df.merge(hit_df.groupby('event_id').size().rename('nhits'), on='event_id')
    hit_df_ = hit_df[['event_id', 'tot_ene', 'nhits']].drop_duplicates()

    hit_df_['port'] = conf_df[conf_df.param_key == '/Generator/IonGenerator/region'].param_value.values[0].replace(' ', '')
    # hit_df_['sim_evs'] = int(conf_df[conf_df.param_key == 'num_events'].param_value.values[0])
    # hit_df_['sav_evs'] = int(conf_df[conf_df.param_key == 'saved_events'].param_value.values[0])
    # hit_df_['file_id'] = int(f.split('/')[-1].split('_')[1])
    return hit_df_

# %%
def get_part_recursive(part_df, out_gammas, all_out_gammas_part = pd.DataFrame()):
    if all_out_gammas_part.empty:
        out_gammas_part = out_gammas[['event_id', 'mother_id']].merge(part_df[['event_id', 'mother_id', 'particle_id', 'particle_name', 'initial_volume']], on = ['event_id', 'mother_id']).rename(columns = {'mother_id':'gamma_mother_id'})
        all_out_gammas_part = all_out_gammas_part.append(out_gammas_part)
    else:
        out_gammas_part = out_gammas.copy()
    next_out_gammas_part = out_gammas_part[['event_id', 'gamma_mother_id', 'particle_id']].rename(\
                                                                            columns = {'particle_id':'mother_id'}).merge(\
                                                                                                                        part_df[['event_id', 'mother_id', 'particle_id', 'particle_name', 'initial_volume']], on = ['event_id', 'mother_id']).drop(columns = 'mother_id')
    all_out_gammas_part = all_out_gammas_part.append(next_out_gammas_part)
    if not next_out_gammas_part.empty:
        get_part_recursive(part_df, next_out_gammas_part, all_out_gammas_part)

    all_out_gammas_part = out_gammas.rename(columns = {'mother_id':'gamma_mother_id'}).merge(all_out_gammas_part, on = ['event_id', 'gamma_mother_id'])
    return all_out_gammas_part

# %%
def get_gamma_products(file):
    port_name = file.split('/')[-3]
    hit_df = load_dst(file, 'MC', 'hits')
    part_df = load_dst(file, 'MC', 'particles')

    hit_df = hit_df[hit_df.label == 'ACTIVE']

    hit_part_ener = hit_df.groupby(['event_id', 'particle_id']).energy.sum().reset_index().rename(columns = {'energy':'hit_energy'})

    #here we change particle_id to mother_id to merge with the particles df and find the sons of the selected gammas; the other values are changed to identify they come from the gammas
    out_gammas = part_df[(part_df.particle_name == 'gamma') & (part_df.creator_proc == 'RadioactiveDecay')][['event_id', 'particle_id','final_volume', 'kin_energy', 'final_proc']].rename(columns = {'particle_id':'mother_id', 'kin_energy':'kin_gamma_energy', 'final_volume':'final_gamma_volume', 'final_proc':'final_gamma_proc'})

    all_out_gammas_part = get_part_recursive(part_df, out_gammas)

    final_out_gammas_part = all_out_gammas_part.merge(hit_part_ener, on = ['event_id', 'particle_id']).groupby(['event_id', 'gamma_mother_id', 'final_gamma_volume', 'kin_gamma_energy', 'final_gamma_proc']).sum().reset_index().drop(columns = 'particle_id')
    final_out_gammas_part['port'] = port_name
    return final_out_gammas_part

# %%
# info_df_208Tl = pd.DataFrame()
# for f in sorted(glob.glob(path.format(isotope='208Tl', port='*')), key = lambda x: (x.split('/')[-3], int(x.split('_')[-2]))):
#     info_df_208Tl = info_df_208Tl.append(get_mc_info(f))

# %%
# gamma_part_df = pd.DataFrame()
# for f in sorted(glob.glob(nexus_path.format(isotope='208Tl', port='*')), key = lambda x: (x.split('/')[-3], int(x.split('_')[-2]))):
#     gamma_part_df = gamma_part_df.append(get_gamma_products(f))

# %%
sim_evs_info = pd.DataFrame([{'sim_evs_per_file': nevent_per_file, 'sim_files_per_port': nfiles_per_port, 'n_ports':nport}])

# %%
save_path_208Tl = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/summary_208Tl.h4'
# info_df_208Tl.to_hdf(save_path_208Tl, key = 'events_info') 
# sim_evs_info.to_hdf(save_path_208Tl, key = 'sim_info')

# %%
save_path_gammas_208Tl = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/summary_gammas_208Tl.h4'
# gamma_part_df.to_hdf(save_path_gammas_208Tl, key = 'gammas_info')

# %%
info_df_208Tl = pd.read_hdf(save_path_208Tl, 'events_info')
sim_evs_info = pd.read_hdf(save_path_208Tl, 'sim_info')
gamma_part_df = pd.read_hdf(save_path_gammas_208Tl, 'gammas_info')

# %%
size_path = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/size_data.txt'
with open(size_path, 'r') as f:
        text = f.readlines()
        f.close()
folder_size = [[t.split("\t")[1].split('/')[1].rstrip('\n'),float(t.split("\t")[0].rstrip('G').replace(',', '.'))] for t in text[:-2]]
size_df = pd.DataFrame(folder_size, columns = ['port', 'size'])

# %%
size_df
# Out:
#       port   size
# 0  PORT_2b  357.0
# 1  PORT_1a  371.0
# 2  PORT_1b  355.0
# 3  PORT_2a  270.0

# %%
def print_effs_and_sim(df, isotope, size_df, e_threshold = (0, np.inf), nevents_per_port = nevents_per_port, nevents = nevent_per_file, desired_events = 1e6, round_factor = 1e5, target_evs_file = 2e4):
    df = df[(df.tot_ene > e_threshold[0]) & (df.tot_ene < e_threshold[1])]
    size_df = size_df.set_index('port')['size']
    port_eff = df.groupby('port').size() / nevents_per_port

    print('MC efficiencies ({} < E < {})'.format(e_threshold[0], e_threshold[1]))
    print('Each port:')
    print(port_eff)
    print('')

    print('Total efficiency')
    print(len(df) / nevents)

    print('')
    print('In each port we will need to simulate (to have at least 1M events):')
    print(desired_events / port_eff)

    print('')
    print('Which we can set up to:')
    target_evs_port = np.ceil((desired_events / port_eff).max() / round_factor) * round_factor
    print(target_evs_port, ' events per port')
    print(target_evs_port / target_evs_file, ' tasks/files per port if we simulate ', target_evs_file, ' events per file')
    print('With the current eff, these files will have around ', target_evs_file * port_eff.mean(), ' events per file')
    print('')
    print('For having 1M, we expect that the production will occupy:')
    expected_size = size_df / df.groupby('port').size() * desired_events
    print(expected_size)
    print('In total: {} G'.format(expected_size.sum()))
    return port_eff, expected_size

# %%
#_, _ = print_effs_and_sim(info_df_208Tl, '208Tl', size_df)

# %%
#port_eff_208Tl, exp_size_208Tl = print_effs_and_sim(info_df_208Tl, '208Tl', size_df, e_threshold=(0.4, np.inf))

# %%
#_, _ = print_effs_and_sim(info_df_208Tl, '208Tl', size_df, e_threshold=(1.45, 1.75))

# %% [markdown]
# Esta eff coincide aprox con la que tenía Gonzalo para ese rango de energía (0.007), yo quizás tengo menos estadística

# %% [markdown]
# #### Vamos a plotear un esquema del cilindro con las eff para cada puerto

# %%
sim_evs_info
# Out:
#    sim_evs_per_file  sim_files_per_port  n_ports
# 0             20000                 660        4

# %%
info_df_208Tl.count()
# Out:
# event_id    4446931
# tot_ene     4446931
# nhits       4446931
# port        4446931
# dtype: int64

# %%
# Cylinder surface parameters
radius = 67.555
zmin = -84
zmax = +84
resolution = 200  # Number of points to approximate the cylinder's surface

def cylinder_surface(rad, zmin, zmax, resol):
    # Create points for the cylinder's surface
    theta = np.linspace(0, 2 * np.pi, resol)
    z = np.linspace(zmin, zmax, resol)
    Theta, Z = np.meshgrid(theta, z)
    X = rad * np.cos(Theta)
    Y = rad * np.sin(Theta)
    return X, Y, Z

# Ports of the cylinder
port_x = (47.77, 47.477, -47.77, -47.77)
port_y = (47.77, 47.477,  47.77,  47.77)
port_z = (-13.95, 45.05, -30.79, 19.21)
port_n = ('PORT_1a', 'PORT_2a', 'PORT_1b', 'PORT_2b')
port_info = [port_x, port_y, port_z, port_n]

# Eff for each port in a energy range
e_range = (0.4, np.inf)
port_eff_208Tl, exp_size_208Tl = print_effs_and_sim(info_df_208Tl, '208Tl', size_df, e_threshold=e_range)
# Out:
# MC efficiencies (0.4 < E < inf)
# Each port:
# port
# PORT_1a    0.093867
# PORT_1b    0.090218
# PORT_2a    0.064778
# PORT_2b    0.088027
# dtype: float64
#
# Total efficiency
# 222.34655
#
# In each port we will need to simulate (to have at least 1M events):
# port
# PORT_1a    1.065341e+07
# PORT_1b    1.108430e+07
# PORT_2a    1.543742e+07
# PORT_2b    1.136019e+07
# dtype: float64
#
# Which we can set up to:
# 15500000.0  events per port
# 775.0  tasks/files per port if we simulate  20000.0  events per file
# With the current eff, these files will have around  1684.4435606060604  events per file
#
# For having 1M, we expect that the production will occupy:
# port
# PORT_1a    299.425362
# PORT_1b    298.100387
# PORT_2a    315.765468
# PORT_2b    307.241607
# dtype: float64
# In total: 1220.53282369377 G

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

fig = plt.figure(figsize = (12, 6))

cyl_surf = cylinder_surface(radius, zmin, zmax, resolution)

def plot_next100_scheme(fig, subplot, cyl_surf, port_info, port_eff, ang = (0, 0)):
    # Create a 3D figure
    
    ax = fig.add_subplot(subplot, projection='3d')

    # Plot the surface of the cylinder
    X, Y, Z = cyl_surf[0], cyl_surf[1], cyl_surf[2]
    ax.plot_surface(X, Y, Z, color='b', alpha= 0.3)

    # Plot the ports of the cylinder
    port_x, port_y, port_z, port_n = port_info
    ax.scatter(port_x[0], port_y[0], port_z[0], marker='o', s=70, label=port_n[0] + ' ($\epsilon$ = {:.4})'.format(port_eff[port_n[0]]))
    ax.scatter(port_x[1], port_y[1], port_z[1], marker='o', s=70, label=port_n[1] + ' ($\epsilon$ = {:.4})'.format(port_eff[port_n[1]]))
    ax.scatter(port_x[2], port_y[2], port_z[2], marker='o', s=70, label=port_n[2] + ' ($\epsilon$ = {:.4})'.format(port_eff[port_n[2]]))
    ax.scatter(port_x[3], port_y[3], port_z[3], marker='o', s=70, label=port_n[3] + ' ($\epsilon$ = {:.4})'.format(port_eff[port_n[3]]))

    
    # Set axis labels
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.view_init(elev=ang[0], azim=ang[1]) 
    return ax

plt.suptitle('MC efficiencies ({} < E < {})'.format(e_range[0], e_range[1]), fontsize=16)
fig.text(0.5, 0.02, 'Total efficiency: {:.4} \n Total expected size (for 1M in each port): {:.3} T'.format(port_eff_208Tl.mean(), exp_size_208Tl.sum() / 1000), ha='center', fontsize=16)
ax = plot_next100_scheme(fig, 121, cyl_surf, port_info, port_eff_208Tl, ang=(0, -90))
ax.legend()
ax = plot_next100_scheme(fig, 122, cyl_surf, port_info, port_eff_208Tl, ang=(90, 270))
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.hist(info_df_208Tl.tot_ene, 300)
plt.title('208Tl energy spectra')
plt.xlabel('Energy (MeV)')
plt.show()

# %% [markdown]
# ## 208Tl isaura info @13.5bar

# %%
path = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/{isotope}/prod/{port}/prod/{city}/*.h5'

# %%
def get_pao_info(f):
    pao_sum = load_dst(f, 'Summary', 'Events')
    pao_trk = load_dst(f, 'Tracking', 'Tracks')

    pao_sum = pao_sum[['event', 'evt_energy', 'evt_ntrks', 'evt_nhits']]
    pao_trk = pao_trk[['event', 'trackID', 'energy', 'length', 'numb_of_tracks', 'numb_of_voxels', 'numb_of_hits', 'eblob1', 'eblob2', 'ovlp_blob_energy']]

    pao_sum['port'] = f.split('/')[-4]
    pao_trk['port'] = f.split('/')[-4]
    
    return pao_sum, pao_trk

# %%
def write_pao_summary(path, city, save_path = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calibration/208Tl/prod/{city}_summary_208Tl.h4'):

    paolina_summary, paolina_tracks = pd.DataFrame(), pd.DataFrame()

    for f in sorted(glob.glob(path.format(isotope = '208Tl', port='*', city = city)), key = lambda x: (x.split('/')[-4], int(x.split('_')[-2]))):
        sum_, trk_ = get_pao_info(f)
        paolina_summary = paolina_summary.append(sum_)
        paolina_tracks = paolina_tracks.append(trk_)
    paolina_summary.to_hdf(save_path.format(city = city), key = 'summary') 
    paolina_tracks.to_hdf(save_path.format(city = city), key = 'tracks')

# %%
save_path_paolina = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calibration/208Tl/prod/{city}_summary_208Tl.h4'

# write_pao_summary(path, 'esmeralda', save_path = save_path_paolina)
# write_pao_summary(path, 'isaura', save_path = save_path_paolina)

# %%
isaura_summary = pd.read_hdf(save_path_paolina.format(city = 'isaura'), 'summary')
isaura_tracks = pd.read_hdf(save_path_paolina.format(city = 'isaura'), 'tracks')

esmeralda_summary = pd.read_hdf(save_path_paolina.format(city = 'esmeralda'), 'summary')
esmeralda_tracks = pd.read_hdf(save_path_paolina.format(city = 'esmeralda'), 'tracks')

# %%
plt.hist(esmeralda_summary.evt_energy, 300, histtype='step')
plt.xlabel('Energy')
plt.show()

plt.hist(esmeralda_summary.evt_ntrks, esmeralda_summary.evt_ntrks.max(), range = (esmeralda_summary.evt_ntrks.min(), esmeralda_summary.evt_ntrks.max() + 1))
plt.xlabel('# of tracks')
plt.show()

plt.hist(esmeralda_summary.evt_nhits, 100, histtype='step')
plt.xlabel('# of hits')
plt.show()

# %%
plt.hist(isaura_summary.evt_energy, 300, histtype='step')
plt.xlabel('Energy')
plt.show()

plt.hist(isaura_summary.evt_ntrks, isaura_summary.evt_ntrks.max(), range = (isaura_summary.evt_ntrks.min(), isaura_summary.evt_ntrks.max() + 1))
plt.xlabel('# of tracks')
plt.show()

plt.hist(isaura_summary.evt_nhits, 100, histtype='step')
plt.xlabel('# of hits')
plt.show()

# %%
isa_main_trk = isaura_tracks[isaura_tracks.trackID == 0]

plt.hist(isa_main_trk.energy, 100, histtype='step')
plt.xlabel('E (MeV)')
plt.title('Main tracks energy')
plt.show()

plt.hist(isa_main_trk.length, 100, histtype='step')
plt.xlabel('L (cm)')
plt.title('Main tracks length')
plt.show()

plt.hist(isa_main_trk.numb_of_voxels, 100, histtype='step')
plt.xlabel('# of voxels')
plt.title('Main tracks # of voxels')
plt.show()

plt.hist(isa_main_trk.numb_of_hits, 100, histtype='step')
plt.xlabel('# of hits')
plt.title('Main tracks # of hits')
plt.show()

plt.hist(isa_main_trk.eblob1, 100, histtype='step')
plt.xlabel('E (MeV)')
plt.title('Main tracks blob1 energy')
plt.show()

plt.hist(isa_main_trk.eblob2, 100, histtype='step')
plt.xlabel('E (MeV)')
plt.title('Main tracks blob2 energy')
plt.show()

plt.hist(isa_main_trk.eblob1, 100, histtype='step', label = 'eblob1')
plt.hist(isa_main_trk.eblob2, 100, histtype='step', label = 'eblob2')
plt.xlabel('E (MeV)')
plt.title('Main tracks blob energy comparison')
plt.legend()

plt.show()

# %% [markdown]
# ## MC isaura analysis

# %%
mc_path = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/*/nexus_compr/*.h5'
#mc_track_path = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/*/nexus_compr/tracks/*.h5'

# %%
files = sorted(glob.glob(mc_path), key = lambda x: (x.split('/')[-3], int(x.split('_')[-2])))
f = files[1]

# %%
f_tr = f.replace('nexus_compr/nexus', 'nexus_compr/tracks/nexus').replace('208Tl.h5', 'tracks_trueinfo.h5')

# %%
def ene_fid_cuts(hits, e_cut = (1.4, 1.8), fid_R = 450, fid_z = (20, 1180)):
    inf_e, sup_e = e_cut
    inf_z, sup_z = fid_z
    hits['R'] = np.sqrt(hits.x**2 + hits.y**2)
    mask_r = hits.groupby('event_id').apply(lambda x: False if (x.R > fid_R).any() else True)
    mask_z = hits.groupby('event_id').apply(lambda x: False if (x.z > sup_z).any() or (x.z < inf_z).any() else True)
    mask_e = hits.groupby('event_id').apply(lambda x: False if (x.energy.sum() > sup_e).any() or (x.energy.sum() < inf_e).any() else True)
    mask = (mask_r & mask_z & mask_e)
    hits = hits[hits['event_id'].isin(mask.loc[mask].reset_index()['event_id'])]
    return hits

label_evs = lambda particles: particles.rename(columns = {'event_id':'event'}).groupby('event').apply(lambda x: 1 if np.isin('e+', x.particle_name) else 0).rename('label')

# %%
def label_events_df(f, label):
    sig = sum(label)
    bkg = len(label) - sig
    port = f.split('/')[-3]
    nfil = int(f.split('/')[-1].split('_')[-2])

    event_label = pd.DataFrame([[sig, bkg, port, nfil]], columns = ['sig', 'bkg', 'port', 'nfil'])
    return event_label

# %%
def create_fom(tracks, eblob2_range = np.arange(0, 0.6, 0.02)):
    tracks_ed = tracks.copy()
    for eblob2 in eblob2_range:
        tracks_ed[f'eblob2_{eblob2}'] = (tracks_ed.eblob2 > eblob2)
    return tracks_ed

# %%
def track_fom(f, e_cut = (1.4, 1.8), fid_R = 450, fid_z = (20, 1180), eblob2_range = np.arange(0, 0.6, 0.02)):
    hits   = load_dst(f, 'MC', 'hits')
    part   = load_dst(f, 'MC', 'particles')
    f_tr = f.replace('nexus_compr/nexus', 'nexus_compr/tracks/nexus').replace('208Tl.h5', 'tracks_trueinfo.h5')
    tracks = pd.read_hdf(f_tr, 'Tracks')

    #selection cuts and label events
    hits = ene_fid_cuts(hits, e_cut = e_cut, fid_R = fid_R, fid_z = fid_z)
    label = label_evs(part)

    tracks = tracks.merge(label, on ='event')
    tracks = tracks[np.isin(tracks.event, hits.event_id.unique()) & (tracks.numb_of_tracks == 1) & (tracks.ovlp_blob_energy <= 0)]


    ev_label = label_events_df(f, label)
    tracks['port'] = f.split('/')[-3]
    fom_tracks = create_fom(tracks, eblob2_range = eblob2_range)
    return ev_label, fom_tracks

# %%
save_path_fom = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/fom_208Tl.h5'

for f in files:
    ev_label, fom_tracks = track_fom(f, eblob2_range=np.arange(0, 1, 0.02))
    ev_label.to_hdf(save_path_fom, key = 'label_info', append = True) 
    fom_tracks.to_hdf(save_path_fom, key = 'fom', append = True)

# %%
fom = pd.read_hdf(save_path_fom, 'fom')

# %%
sig = fom.label.sum()
bkg = len(fom) - sig

sig_eff = fom[fom.label == 1].sum().iloc[37:] / sig
bkg_eff = fom[fom.label == 0].sum().iloc[37:] / bkg
fom_values = sig_eff / bkg_eff.apply(lambda x: np.sqrt(x))

# %%
plt.plot(1 - bkg_eff, sig_eff, '.', label = 'HPR')
plt.xlabel('Background rejection')
plt.ylabel('Signal efficiency')
plt.xticks(np.arange(0, 1.2, 0.2))
plt.grid()
plt.legend()
plt.show()

plt.plot(np.arange(0, 1, 0.02), fom_values, '.', label = 'HPR')
plt.xlabel('Blob2 cut (keV)')
plt.ylabel('f.o.m.')
plt.legend()
plt.grid()

# %%
path = '/mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/{isotope}/prod/{port}/prod/{city}/*.h5'
files = sorted(glob.glob(path.format(isotope = '208Tl', port='*', city = 'esmeralda')), key = lambda x: (x.split('/')[-4], int(x.split('_')[-2])))

chits_all = np.array([])
summa_all = np.array([])
track_all = np.array([])

for f in files:
    print(f)
    chits = load_dst(f, 'CHITS', 'highTh').groupby('event').sum().Ec.values
    summary = load_dst(f, 'Summary', 'Events').evt_energy.values
    tracks = load_dst(f, 'Tracking', 'Tracks').groupby('event').sum().energy.values
    chits_all = np.append(chits_all, chits)
    summa_all = np.append(summa_all, summary)
    track_all = np.append(track_all, tracks)
    
    assert np.isclose(chits, summary).all(), f
    assert np.isclose(chits, tracks).all(), f
    assert np.isclose(summary, tracks).all(), f
# Out:
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_1_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_2_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_3_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_4_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_5_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_6_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_7_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_8_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_9_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_10_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_11_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_12_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_13_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_14_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_15_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_16_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_17_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_18_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_19_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_20_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_21_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_22_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_23_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_24_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_25_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_26_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_27_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_28_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_29_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_30_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_31_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_32_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_33_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_34_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_35_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_36_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_37_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_38_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_39_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_40_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_41_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_42_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_43_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_44_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_45_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_46_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_47_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_48_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_49_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_50_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_51_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_52_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_53_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_54_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_55_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_56_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_57_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_58_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_59_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_60_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_61_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_62_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_63_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_64_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_65_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_66_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_67_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_68_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_69_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_70_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_71_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_72_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_73_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_74_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_75_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_76_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_77_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_78_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_79_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_80_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_81_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_82_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_83_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_84_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_85_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_86_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_87_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_88_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_89_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_90_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_91_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_92_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_93_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_94_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_95_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_96_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_97_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_98_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_99_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_100_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_101_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_102_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_103_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_104_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_105_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_106_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_107_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_108_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_109_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_110_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_111_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_112_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_113_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_114_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_115_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_116_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_117_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_118_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_119_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_120_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_121_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_122_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_123_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_124_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_125_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_126_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_127_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_128_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_129_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_130_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_131_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_132_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_133_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_134_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_135_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_136_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_137_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_138_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_139_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_140_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_141_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_142_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_143_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_144_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_145_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_146_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_147_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_148_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_149_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_150_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_151_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_152_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_153_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_154_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_155_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_156_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_157_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_158_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_159_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_160_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_161_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_162_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_163_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_164_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_165_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_166_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_167_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_168_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_169_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_170_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_171_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_172_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_173_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_174_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_175_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_176_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_177_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_178_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_179_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_180_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_181_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_182_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_183_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_184_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_185_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_186_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_187_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_188_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_189_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_190_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_191_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_192_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_193_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_194_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_195_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_196_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_197_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_198_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_199_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_200_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_201_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_202_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_203_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_204_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_205_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_206_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_207_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_208_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_209_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_210_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_211_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_212_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_213_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_214_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_215_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_216_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_217_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_218_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_219_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_220_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_221_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_222_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_223_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_224_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_225_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_226_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_227_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_228_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_229_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_230_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_231_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_232_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_233_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_234_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_235_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_236_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_237_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_238_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_239_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_240_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_241_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_242_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_243_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_244_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_245_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_246_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_247_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_248_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_249_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_250_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_251_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_252_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_253_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_254_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_255_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_256_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_257_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_258_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_259_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_260_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_261_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_262_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_263_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_264_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_265_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_266_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_267_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_268_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_269_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_270_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_271_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_272_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_273_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_274_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_275_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_276_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_277_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_278_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_279_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_280_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_281_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_282_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_283_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_284_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_285_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_286_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_287_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_288_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_289_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_290_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_291_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_292_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_293_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_294_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_295_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_296_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_297_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_298_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_299_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_300_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_301_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_302_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_303_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_304_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_305_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_306_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_307_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_308_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_309_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_310_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_311_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_312_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_313_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_314_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_315_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_316_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_317_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_318_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_319_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_320_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_321_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_322_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_323_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_324_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_325_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_326_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_327_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_328_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_329_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_330_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_331_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_332_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_333_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_334_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_335_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_336_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_337_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_338_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_339_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_340_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_341_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_342_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_343_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_344_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_345_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_346_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_347_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_348_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_349_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_350_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_351_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_352_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_353_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_354_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_355_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_356_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_357_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_358_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_359_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_360_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_361_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_362_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_363_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_364_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_365_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_366_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_367_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_368_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_369_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_370_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_371_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_372_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_373_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_374_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_375_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_376_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_377_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_378_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_379_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_380_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_381_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_382_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_383_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_1a/prod/esmeralda/esmeralda_384_208Tl.h5
# ...
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_533_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_534_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_535_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_536_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_537_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_538_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_539_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_540_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_541_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_542_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_543_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_544_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_545_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_546_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_547_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_548_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_549_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_550_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_551_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_552_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_553_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_554_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_555_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_556_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_557_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_558_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_559_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_560_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_561_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_562_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_563_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_564_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_565_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_566_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_567_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_568_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_569_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_570_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_571_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_572_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_573_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_574_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_575_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_576_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_577_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_578_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_579_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_580_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_581_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_582_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_583_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_584_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_585_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_586_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_587_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_588_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_589_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_590_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_591_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_592_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_593_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_594_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_595_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_596_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_597_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_598_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_599_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_600_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_601_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_602_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_603_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_604_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_605_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_606_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_607_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_608_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_609_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_610_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_611_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_612_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_613_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_614_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_615_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_616_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_617_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_618_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_619_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_620_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_621_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_622_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_623_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_624_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_625_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_626_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_627_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_628_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_629_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_630_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_631_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_632_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_633_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_634_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_635_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_636_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_637_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_638_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_639_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_640_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_641_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_642_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_643_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_644_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_645_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_646_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_647_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_648_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_649_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_650_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_651_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_652_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_653_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_654_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_655_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_656_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_657_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_658_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_659_208Tl.h5
# /mnt/lustre/scratch/nlsas/home/usc/ie/mpm/NEXT100/data/HE_calib/HPR/208Tl/prod/PORT_2b/prod/esmeralda/esmeralda_660_208Tl.h5

# %%
e_th = 0.4

chits_all_ = chits_all[chits_all > e_th]
summa_all_ = summa_all[summa_all > e_th]
track_all_ = track_all[track_all > e_th]

plt.figure(figsize=(10, 7))
plt.hist(chits_all, 300, histtype='step', density = True, label = 'From CHITS, sum(Ec)')
plt.hist(summa_all, 300, histtype='step', density = True, label = 'From summary')
plt.hist(track_all, 300, histtype='step', density = True, label = 'From tracks')
plt.yscale('log')
plt.legend()
plt.xlabel('Energy (MeV)')
plt.title(r'$^{208}$Tl event energy spectra (E > 0.4 MeV)')
plt.grid()
plt.show()

# %%
def line(x, x0, x1, y0, y1):
    m = (y1 - y0) / (x1 - x0)
    y = m * (x - x0) + y0
    print(m)
    print(y)

# %%
line(80, 25, 55, 0.83, 0.96)
# Out:
# 0.004333333333333333
# 1.0683333333333334

# %%
line(80, 40, 55, 1000, 890)
# Out:
# -7.333333333333333
# 706.6666666666667

# %%
line(29.62, 25, 55, 4110, 3480)
# Out:
# -21.0
# 4012.98

# %%
4012.98 / np.sqrt(13.5)
# Out:
# 1092.194816443782

# %%
(9.01333 + 3.01605) / (9.01333 + 3.01605 - 3.016029)
# Out:
# 1.3346179462000314

# %%
def Q(Ta, Tb):
    q = Tb * (1 + 1.007825/131.904144) - Ta * (1 - 2.014102/131.904144)
    return q

# %%
Q(2, 8.5484) - Q(2, 7.155)
# Out:
# 1.4040463929973264

# %%
1.262 - 0.631
# Out:
# 0.631

# %%
6.680-5.382
# Out:
# 1.298

# %%
(7.016003 + 1.007825 - 1.008665 - 7.016929) * 931.494
# Out:
# -1.645018403999939

# %%
(7.016929 * (1.75 - 5 + 1.645018403999939) + 5*1.007825 + 1.75*1.008665) / (2*np.sqrt(1.007825 * 1.008665 * 1.75 * 5))
# Out:
# -0.7473360884961371

# %%
np.arccos(-0.7473360884961371) * 180 / np.pi
# Out:
# 138.3601455687089

# %%
np.arctan(0.05) * 180 /np.pi
# Out:
# 2.8624052261117474

# %%
def Tb(ma, mb, mB, Ta, theta, Q):
    r = np.sqrt(ma*mb*Ta)* np.cos(theta) / (mB + mb)
    s = (Ta * (mB - ma) + mB * Q) / (mB + mb)
    raiz = np.sqrt(r**2 + s)
    return r + raiz, r - raiz

# %%
Tb(1.007825, 1.008665, 7.016929, 5, np.arccos(-0.7473360884961371) + np.arctan(0.05), -1.645018403999939)
# Out:
# (1.3150836009012439, -1.7530764922959188)

# %%
1.33117548704805329**2 - 1.3150836009012439**2
# Out:
# 0.04258329995823962

# %%
1.75 * (114.903878772 / (114.903878772 + 1.008665)) + (114.903878772 + 1.008665 - 115.90525999) * 931.494
# Out:
# 8.519570820216225

# %%
(114.903878772 + 1.008665 - 115.90525999) * 931.494
# Out:
# 6.784799230296433

# %%
def el_gain(p, E, d = 1):
    a = 140.
    if (p >= 2.): a = 141. 
    if (p >= 4.): a = 142.
    if (p >= 5.): a = 151.
    if (p >= 6.): a = 161.
    if (p >= 8.): a = 170.
    #gonzalito
    gel_1 = a * (E/p - 0.75)  * p * d
    #monteiro
    gel_2 = (a * E / p - 116) * p * d 
    #freitas
    gel_3 = (a * E / p - 131) * p * d
    return gel_1, gel_2, gel_3

# %%
el_gain(13.5, 17.5)
# Out:
# (1253.75, 1409.0000000000002, 1206.5000000000002)

# %%
el_gain(5, 10)
# Out:
# (943.75, 930.0, 855.0)

# %%
x = 5.891
1.9421 + x * 12/13
# Out:
# 7.379946153846154

# %%
41.25+13.50
# Out:
# 54.75
